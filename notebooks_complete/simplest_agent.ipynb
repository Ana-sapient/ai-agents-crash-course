# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """,
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Bananas are quite healthy as part of a balanced diet.
#
#     Pros:
#     - Good source of potassium, vitamin B6, vitamin C, and dietary fiber
#     - Low to moderate calories (about 100 calories per medium banana)
#     - Convenient, portable, and naturally sweet
#
#     Considerations:
#     - Contain natural sugars; portion matters if you’re watching blood sugar or calories
#     - Very high potassium isn’t a concern for most, but people with kidney issues should monitor intake
#     - Unripe (green) bananas have more resistant starch; ripe ones have more sugar
#
#     Bottom line: a medium banana daily fits well in most healthy diets.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Generally healthy as part of a balanced diet.
#
# Key benefits:
# - Good source of potassium (supports blood pressure/heart health) and vitamin B6.
# - Provides vitamin C, fiber, and quick energy from natural sugars.
# - Easy to digest and convenient.
#
# Nutrients in a medium banana (about 118 g):
# - ~105 calories, ~27 g carbs, ~3 g fiber, ~14 g sugar, ~1 g protein.
#
# Things to consider:
# - Higher sugar/carbs in ripe bananas; portion if you’re watching sugar or carb intake.
# - Allergies or sensitivities are rare but possible.
#
# Bottom line: a nutritious, convenient snack or add-on most days.

# %% [markdown]
# _Good Job!_
